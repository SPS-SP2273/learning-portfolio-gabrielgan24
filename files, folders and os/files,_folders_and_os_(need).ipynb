# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders and OS (Need)</span></div>

# %% [markdown]
# ## 1 Important concepts

# %% [markdown]
# ### 1.1 Path

# %%
# tells us how to find a file/folder

# %% [markdown]
# ### 1.2 More about relative paths

# %%
#. ==> 'this folder'
#. . ==> 'one folder above'

#FOR MAC ==> '~' used to refer to home directory 
#e.g. ~/Desktop

# %% [markdown]
# ### 1.3 Path separator

# %%
# FOR MAC ==> / as path seperator

# %% [markdown]
# ### Text files vs Binary files

# %%
# TEXT FILES: simple and can be opened (.txt, .md, .csv)

# BINARY FILES: some processing required (.png, excel.exe)

# %% [markdown]
# ### Extentions

# %%
# Your code here

# %% [markdown]
# ### 1.4 Opening and closing files

# %%
#READING DATA

with open('spectrum-01.txt', 'r') as file:    #OPEN FUNCTION
    file_content = file.read()

print(file_content)
# Out:
# Light Intensity, Ch A vs Actual Angular Position, Run #4
# Actual Angular Position (  )	Light Intensity, Ch A ( % max )
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.3
# 0.000	-0.2
# 0.000	-0.2
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.004	-0.1
# 0.010	-0.2
# 0.018	-0.2
# 0.024	-0.3
# 0.029	-0.3
# 0.033	-0.3
# 0.036	-0.2
# 0.039	-0.1
# 0.043	-0.1
# 0.047	-0.1
# 0.053	-0.1
# 0.060	-0.1
# 0.066	-0.1
# 0.069	-0.1
# 0.073	-0.1
# 0.076	-0.1
# 0.079	-0.1
# 0.081	-0.1
# 0.082	-0.1
# 0.083	-0.2
# 0.083	-0.2
# 0.086	-0.2
# 0.090	-0.2
# 0.095	-0.2
# 0.100	-0.3
# 0.103	-0.3
# 0.104	-0.2
# 0.105	-0.3
# 0.107	-0.2
# 0.110	-0.2
# 0.115	-0.1
# 0.122	-0.2
# 0.128	-0.1
# 0.134	-0.2
# 0.139	-0.1
# 0.144	-0.2
# 0.150	-0.2
# 0.157	-0.2
# 0.164	-0.2
# 0.170	-0.3
# 0.175	-0.3
# 0.180	-0.2
# 0.185	-0.2
# 0.191	-0.1
# 0.195	-0.1
# ...

# %%
#WRITE DATA

# r ==> for reading
# w ==> for writing

text = 'Far out in the uncharted backwaters of the unfashionable end of the western spiral arm of the Galaxy lies a small unregarded yellow sun.\nOrbiting this at a distance of roughly ninety-two million miles is an utterly insignificant little blue green planet whose ape-descended life forms are so amazingly primitive that they still think digital watches are a pretty neat idea.'

# %%
#write ALL AT ONE GO

with open('my-text-once.txt', 'w') as file:
    file.write(text)

# %%
#write ONE LINE AT A TIME

with open('my-text-lines.txt', 'w') as file:
    for line in text.splitlines():
        file.writelines(line)

# %% [markdown]
# ## 2 Playing with the OS

# %% [markdown]
# ### 2.1 Some packages

# %%
import os      #talk to os
import glob    #search for files
import shutil  #copy files

# %% [markdown]
# ### 2.2 OS safe paths

# %%
path = os.path.join('.', 'all-data', 'sg-data', 'data-01.txt')
print(path)
# Out:
# ./all-data/sg-data/data-01.txt

# %% [markdown]
# ### 2.3 Creating folders

# %%
os.mkdir('people')

for person in ['Jonh', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    print(f'Creating {path}')
    os.mkdir(path)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 os.mkdir('people')
#       3 for person in ['Jonh', 'Paul', 'Ringo']:
#       4     path = os.path.join('people', person)
#
# FileExistsError: [Errno 17] File exists: 'people'

# %% [markdown]
# ### 2.4 Checking for existence

# %%
#USING TRY-EXCEPT
#FileExistError

for person in ['Jonh', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    try:
        os.mkdir(path)
        print(f'Creating {path}')
    except FileExistsError:
        print(f'{path} already exists; skipping creation.')

# %%
#USING OS.PATH.EXIST()  
#os.path.exists()

for person in ['Jonh', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    if os.path.exists(path):
        print(f'{path} already exists; skipping creation.')
    else:
        os.mkdir(path)
        print(f'Creating {path}')

# %% [markdown]
# ### 2.5 Copying files

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    path_to_destination = os.path.join('people', person)
    shutil.copy('sp2273_logo.png', path_to_destination)
    print(f'Copied file to {path_to_destination}')

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    # Create folder 'imgs'
    path_to_imgs = os.path.join('people', person, 'imgs')
    if not os.path.exists(path_to_imgs):
        os.mkdir(path_to_imgs)

    # Move logo file
    current_path_of_logo = os.path.join('people', person, 'sp2273_logo.png')
    new_path_of_logo = os.path.join('people', person, 'imgs', 'sp2273_logo.png')

    shutil.move(current_path_of_logo, new_path_of_logo)
    print(f'Moved logo to {new_path_of_logo}')

# %% [markdown]
# ### 2.6 Listing files

# %%
#all files in directory 
# * known as wildcard => means 'anything'

glob.glob('*')

# %%
glob.glob('peo*/*')

# %%
#search whole folder people

glob.glob('people/**', recursive=True) #first seach recursively

# %%
#find only .png image

glob.glob('people/**/*.png', recursive=True)

# %% [markdown]
# ### 2.7 Moving about

# %%
# getcwd ==> get Current Working Directory

os.getcwd()

# %%
os.chdir('people/Ringo')  #chdir => change into directory

# %% [markdown]
# ### 2.8 Extracting Info

# %%
# extract filename & extension

path = 'people/Ringo/imgs/sp2273_logo.png'
filename = path.split(os.path.sep)[-1]   #os.path.sep => path seperator for os
extension = filename.split('.')[-1]
print(filename, extension)

# %%
path = 'people/Ringo/imgs/sp2273_logo.png'

os.path.split(path)      # Split filename from the rest

# %%
os.path.splitext(path)   # Split extension

# %%
os.path.dirname(path)    # Show the directory

# %% [markdown]
# ### 2.9 Deleting stuff

# %%
os.getcwd()
# Remove a file

# os.remove('imgs/sp2273_logo.png')

# os.path.exists('people/Ringo/imgs/sp2273_logo.png')

# %%
#for empty directory => os.rmdir('people/Ringo')

# %%
#for directory with file => shutil.rmtree('people/Ringo')

# %% [markdown]
# ## Exercise 7 :  The OS is my oyster

# %%
#1 [check current directory]

os.getcwd()
# Out:
# '/Users/gaby/Documents/Pharmacy/SPS2273/learning-portfolio-gabrielgan24/files, folders and os/people/Ringo'

# %%
#2 [make new directory]
#os.mkdir('python_today')

#os.chdir('python_today')
os.getcwd()
# Out:
# '/Users/gaby/Documents/Pharmacy/SPS2273/learning-portfolio-gabrielgan24/files, folders and os'

# %%
#3
for i in range(1,51):
    path = os.path.join(f'new_directory_{str(i).zfill(2)}')
    os.mkdir(f'new_directory_{str(i).zfill(2)}')

# %%
#4

for i in range(1,51,2):
    os.rmdir(f'new_directory_{str(i).zfill(2)}')
    
sorted(os.listdir())
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'files,_folders_and_os_(need).ipynb',
#  'my-text-lines.txt',
#  'my-text-once.txt',
#  'new_directory_02',
#  'new_directory_04',
#  'new_directory_06',
#  'new_directory_08',
#  'new_directory_10',
#  'new_directory_12',
#  'new_directory_14',
#  'new_directory_16',
#  'new_directory_18',
#  'new_directory_20',
#  'new_directory_22',
#  'new_directory_24',
#  'new_directory_26',
#  'new_directory_28',
#  'new_directory_30',
#  'new_directory_32',
#  'new_directory_34',
#  'new_directory_36',
#  'new_directory_38',
#  'new_directory_40',
#  'new_directory_42',
#  'new_directory_44',
#  'new_directory_46',
#  'new_directory_48',
#  'new_directory_50',
#  'os-collaboration-exercise-data',
#  'people',
#  'sp2273_logo.png',
#  'spectrum-01.txt']

# %%
os.getcwd()

# %%
sorted(os.listdir())
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'files,_folders_and_os_(need).ipynb',
#  'my-text-lines.txt',
#  'my-text-once.txt',
#  'new_directory_02',
#  'new_directory_04',
#  'new_directory_06',
#  'new_directory_08',
#  'new_directory_10',
#  'new_directory_12',
#  'new_directory_14',
#  'new_directory_16',
#  'new_directory_18',
#  'new_directory_20',
#  'new_directory_22',
#  'new_directory_24',
#  'new_directory_26',
#  'new_directory_28',
#  'new_directory_30',
#  'new_directory_32',
#  'new_directory_34',
#  'new_directory_36',
#  'new_directory_38',
#  'new_directory_40',
#  'new_directory_42',
#  'new_directory_44',
#  'new_directory_46',
#  'new_directory_48',
#  'new_directory_50',
#  'os-collaboration-exercise-data',
#  'people',
#  'sp2273_logo.png',
#  'spectrum-01.txt']

# %%
#5

for i in range(5,51,5):
    if os.path.exists(f'new_directory_{str(i).zfill(2)}') == True:
        os.rename(f'new_directory_{str(i).zfill(2)}',f'haha_{str(i).zfill(2)}')
    else: 
        os.mkdir(f'haha_{str(i).zfill(2)}')
sorted(os.listdir())
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'files,_folders_and_os_(need).ipynb',
#  'haha_05',
#  'haha_10',
#  'haha_15',
#  'haha_20',
#  'haha_25',
#  'haha_30',
#  'haha_35',
#  'haha_40',
#  'haha_45',
#  'haha_50',
#  'my-text-lines.txt',
#  'my-text-once.txt',
#  'new_directory_02',
#  'new_directory_04',
#  'new_directory_06',
#  'new_directory_08',
#  'new_directory_12',
#  'new_directory_14',
#  'new_directory_16',
#  'new_directory_18',
#  'new_directory_22',
#  'new_directory_24',
#  'new_directory_26',
#  'new_directory_28',
#  'new_directory_32',
#  'new_directory_34',
#  'new_directory_36',
#  'new_directory_38',
#  'new_directory_42',
#  'new_directory_44',
#  'new_directory_46',
#  'new_directory_48',
#  'os-collaboration-exercise-data',
#  'people',
#  'sp2273_logo.png',
#  'spectrum-01.txt']

# %%
#6

sorted(glob.glob('hah*'))

for laughs in glob.glob('hah*'):
    shutil.copy('/Users/gaby/Documents/Pharmacy/SPS2273/learning-portfolio-gabrielgan24/files, folders and os/sp2273_logo.png', laughs)

# %%
sorted(glob.glob(f'haha*/**'))
# Out:
# []

# %%
#hi darren another mentor say ignore the os.path.sep & os.path.join()

# %%
sorted(os.listdir())
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'files,_folders_and_os_(need).ipynb',
#  'haha_05',
#  'haha_10',
#  'haha_15',
#  'haha_20',
#  'haha_25',
#  'haha_30',
#  'haha_35',
#  'haha_40',
#  'haha_45',
#  'haha_50',
#  'my-text-lines.txt',
#  'my-text-once.txt',
#  'new_directory_02',
#  'new_directory_04',
#  'new_directory_06',
#  'new_directory_08',
#  'new_directory_12',
#  'new_directory_14',
#  'new_directory_16',
#  'new_directory_18',
#  'new_directory_22',
#  'new_directory_24',
#  'new_directory_26',
#  'new_directory_28',
#  'new_directory_32',
#  'new_directory_34',
#  'new_directory_36',
#  'new_directory_38',
#  'new_directory_42',
#  'new_directory_44',
#  'new_directory_46',
#  'new_directory_48',
#  'os-collaboration-exercise-data',
#  'people',
#  'sp2273_logo.png',
#  'spectrum-01.txt']

# %% [markdown]
# ## Exercise 8 :  Tidying a collaboration

# %%
string  = "a_b_c"
print(string.split("_"))
print(string.split("b"))

# %%
#1 & 2

calendar = {'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'}

def rename_my_file(old_file_name):
    new = calendar[old_file_name.split('-')[0]] + '-' + old_file_name.split('-')[1]
    
    return new.replace('_','-')
    

rename_my_file('oct-08_singapore.txt')
# Out:
# '10-08-singapore.txt'

# %%
#3

selected = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

for files in selected:
    print(files, '---->',rename_my_file(files))
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt

# %%
#4  

#for files in sorted(glob.glob(f'*.txt*')):
    #os.rename(files,rename_my_file(files))

# %%
sorted(os.listdir())
# Out:
# ['01-01-manila.txt',
#  '01-01-osaka.txt',
#  '01-02-cairo.txt',
#  '01-02-karachi.txt',
#  '01-02-manila.txt',
#  '01-03-cairo.txt',
#  '01-03-jakarta.txt',
#  '01-03-karachi.txt',
#  '01-03-shanghai.txt',
#  '01-04-cairo.txt',
#  '01-04-jakarta.txt',
#  '01-04-karachi.txt',
#  '01-04-manila.txt',
#  '01-05-cairo.txt',
#  '01-05-melbourne.txt',
#  '01-05-osaka.txt',
#  '01-06-jakarta.txt',
#  '01-06-karachi.txt',
#  '01-06-melbourne.txt',
#  '01-07-cairo.txt',
#  '01-08-cairo.txt',
#  '01-08-manila.txt',
#  '01-08-osaka.txt',
#  '01-08-tokyo.txt',
#  '01-09-cairo.txt',
#  '01-09-karachi.txt',
#  '01-09-manila.txt',
#  '01-09-melbourne.txt',
#  '01-10-jakarta.txt',
#  '01-10-karachi.txt',
#  '01-10-shanghai.txt',
#  '01-11-cairo.txt',
#  '01-11-manila.txt',
#  '01-11-melbourne.txt',
#  '01-12-cairo.txt',
#  '01-12-jakarta.txt',
#  '01-12-karachi.txt',
#  '01-12-melbourne.txt',
#  '01-12-osaka.txt',
#  '01-12-tokyo.txt',
#  '01-13-cairo.txt',
#  '01-13-jakarta.txt',
# ...

# %%
#5

citylist = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

os.mkdir('cities')
for city in ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila', 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']:
    path = os.path.join('cities',city)
    os.mkdir(path)

# %%
#6

#for i in glob.glob('*cairo*'):
    #shutil.copy(i, 'cities/Cairo')

# %%
#7
for j in citylist:
    for i in glob.glob(f'*{j.lower()}*'):
        shutil.copy(i, f'cities/{j}')
